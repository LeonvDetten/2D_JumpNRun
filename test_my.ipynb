# %%
import world
import player
import object
import enemy

# %%
help(player)
# Out:
# Help on module player:
#
# NAME
#     player
#
# CLASSES
#     pygame.sprite.Sprite(builtins.object)
#         Player
#
#     class Player(pygame.sprite.Sprite)
#      |  Player(start_x, start_y, width, height)
#      |
#      |  Method resolution order:
#      |      Player
#      |      pygame.sprite.Sprite
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, start_x, start_y, width, height)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  animation(self, screen)
#      |
#      |  check_enemy_collision(self)
#      |
#      |  getCamOffset(self)
#      |
#      |  getCurrentChunk(self)
#      |
#      |  jump(self, speed)
#      |
#      |  loadSprites(self)
#      |
#      |  main(self, screen)
#      |
#      |  move_y(self)
#      |
#      |  movement(self)
#      |      Handles the movement of the player
#      |      MOVEMENT BASIERT AUF BUCH ... BUCH ANGEBEN
#      |
# ...

# %%
import pygame
help(pygame.sprite.Sprite)
# Out:
# Help on class Sprite in module pygame.sprite:
#
# class Sprite(builtins.object)
#  |  Sprite(*groups)
#  |
#  |  simple base class for visible game objects
#  |
#  |  pygame.sprite.Sprite(*groups): return Sprite
#  |
#  |  The base class for visible game objects. Derived classes will want to
#  |  override the Sprite.update() method and assign Sprite.image and Sprite.rect
#  |  attributes.  The initializer can accept any number of Group instances that
#  |  the Sprite will become a member of.
#  |
#  |  When subclassing the Sprite class, be sure to call the base initializer
#  |  before adding the Sprite to Groups.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, *groups)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  add(self, *groups)
#  |      add the sprite to groups
#  |
#  |      Sprite.add(*groups): return None
#  |
# ...

# %%
import game
# Out:
# 2023-05-08 18:17:36.281 | INFO     | game:__init__:29 - Created game object
# 2023-05-08 18:17:36.338 | INFO     | game:create_window:35 - Created window with size: 1520x800
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import game
#
# File c:\Python\pirate_game\game.py:58
#      54 my_colors = Color()
#      56 clock = pygame.time.Clock()
# ---> 58 player = Player(player_spawn_x, player_spawn_y, 40, 60)
#      59 world = World(my_game.level, block_size, my_colors.GREEN, player)
#      60 player.setWorld(world)
#
# File c:\Python\pirate_game\player.py:19, in Player.__init__(self, start_x, start_y, width, height)
#      17 self.height = height
#      18 self.__create_sprite_container()
# ---> 19 self.loadSprites()
#      21 #self.currentSprite = 0
#      22 self.spriteLoopSpeed = 0.3
#
# ...
